# %% [markdown]
# # HarvardX Online Courses
#
# General information on free online courses from Harvard on edX.org

# %%
! pip install selenium webdriver_manager

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
from time import sleep
import os
import logging


from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service

# %%
logging.getLogger('WDM').setLevel(logging.NOTSET)
os.environ['WDM_LOG'] = 'False'


# Driver set-up
manager = ChromeDriverManager().install().replace("THIRD_PARTY_NOTICES.", '')
os.chmod(manager, 755)
service = Service(manager)
driver = webdriver.Chrome(service=service)

# %%
def get_course_info(course_url, course_name):
  r = requests.get(course_url)
  page = BeautifulSoup(r.text, 'html.parser')
  card = page.find(class_="at-a-glance")
  card = card.find_all('li') if card else []
  card_items = dict([c.text.split(':', 1) for c in card if ':' in c.text])
  fields = ['Subject', 'Level', 'Prerequisites', 'Language', 'Associated skills']
  relevant_fields = dict([(f, card_items.get(f, '').strip() if not 'None' in card_items.get(f, []) else None) for f in fields])
  
  data = dict()
  data['Name'] = course_name
  data['Duration'] = page.find(class_="h4 mb-0").text

  data['Rating'] = page.find(class_="h5 ml-1 mr-3 mb-0")
  data['Rating'] = data['Rating'].text.split()[0] if data['Rating'] else None
  data['Rating'] = float(data['Rating']) if data['Rating'] and not data['Rating'].isalpha() else None

  data['Number of ratings'] = page.find(class_="micro")
  data['Number of ratings'] = data['Number of ratings'].text.split()[0] if data['Number of ratings'] else None
  data['Number of ratings'] = int(data['Number of ratings']) if data['Number of ratings'] and data['Number of ratings'].isdigit() else None
  
  data['Total enrolled students'] = page.find(attrs={"data-test-id": "selector-subheading"})
  data['Total enrolled students'] = data['Total enrolled students'].find(class_="small") if data['Total enrolled students'] else None
  data['Total enrolled students'] = data['Total enrolled students'].text.split()[0] if data['Total enrolled students'] else None
  data['Total enrolled students'] = int(data['Total enrolled students'].replace(',', '')) if data['Total enrolled students'] and not data['Total enrolled students'].isalpha() else None

  data.update(relevant_fields)
  return data


DATASET = []


def get_all_courses(courses_page_url):
  driver.get(courses_page_url)
  try:
    driver.find_element(By.XPATH, ".//button[contains(text(), 'Show')]").click()
  except:
    pass
  container = driver.find_element(By.XPATH, './/*[@data-testid="card-container"]')
  course_cards = container.find_elements(By.XPATH, './/*[@class="base-card-wrapper"]')

  for card in course_cards:
    try:
      url = card.find_element(By.CSS_SELECTOR, 'a').get_attribute('href')
      name = card.find_element(By.XPATH, './/*[@class="pgn__card-header-title-md"]').text.replace('\n', ' ')
      info = get_course_info(url, name)
      DATASET.append(info)
      print(name)
      sleep(3)
    except:
      continue

# %%
get_all_courses("https://www.edx.org/school/harvardx#programs")
# Out:
# CS50's Introduction to Computer Science
# CS50's Introduction to Programming with Python
# CS50's Introduction to Artificial Intelligence with Python
# CS50's Web Programming with Python and JavaScript
# Exercising Leadership: Foundational Principles
# CS50's Introduction to Cybersecurity
# Rhetoric: The Art of Persuasive Writing and Public Speaking
# Building Personal Resilience: Managing Anxiety and Mental He…
# Human Anatomy: Musculoskeletal Cases
# Data Science: R Basics
# Data Science: Machine Learning
# CS50's Introduction to Databases with SQL
# CS50's Introduction to Programming with Scratch
# Remote Work Revolution for Everyone
# Contract Law: From Trust to Promise to Contract
# Managing Happiness
# Entrepreneurship in Emerging Economies
# Data Science: Visualization
# Fundamentals of Neuroscience, Part 1: The Electrical Properti…
# Machine Learning and AI with Python
# Justice
# The Architectural Imagination
# Data Science: Probability
# Calculus Applied!
# Technology Entrepreneurship: Lab to Market
# CS50's Computer Science for Business Professionals
# Introduction to Probability
# Leaders of Learning
# Data Science: Inference and Modeling
# Cell Biology: Mitochondria
# Using Python for Research
# CitiesX: The Past, Present and Future of Urban Life
# Data Science: Linear Regression
# Leadership: Creating Public Value
# Principles of Biochemistry
# PredictionX: Lost Without Longitude
# Food Fermentation: The Science of Cooking with Microbes
# Early Childhood Development: Global Strategies for Impleme…
# Data Science: Productivity Tools
# Data Science: Wrangling
# The Path to Happiness: What Chinese Philosophy Teaches us…
# Introduction to Family Engagement in Education
# The Health Effects of Climate Change
# Data Science: Capstone
# The Opioid Crisis in America
# Religion, Conflict and Peace
# Pyramids of Giza: Ancient Egyptian Art and Archaeology
# High-Dimensional Data Analysis
# U.S. Public Policy: Social, Economic, and Foreign Policies
# Prescription Drug Regulation, Cost, and Access: Current Contr…
# Fat Chance: Probability from the Ground Up
# Bioethics: The Law, Medicine, and Ethics of Reproductive Technolo…
# Introduction to Data Wise: A Collaborative Process to Improve Le…
# Quantitative Methods for Biology
# CS50's Introduction to Programming with R
# Masterpieces of World Literature
# Christianity Through Its Scriptures
# Fundamentals of TinyML
# Fundamentals of Neuroscience, Part 3: The Brain
# Justice Today: Money, Markets, and Morals
# Improving Global Health: Focusing on Quality and Safety
# Islam Through Its Scriptures.
# Buddhism Through Its Scriptures.
# Super-Earths and Life
# Science & Cooking: From Haute Cuisine to Soft Matter Science (chemi…
# American Government: Constitutional Foundations
# Tangible Things: Discovering History Through Artworks, Art…
# Energy Within Environmental Constraints
# Science & Cooking: From Haute Cuisine to Soft Matter Science (physics)
# Ciencia de Datos: Fundamentos de R
# Shakespeare's Life and Work
# Backyard Meteorology: The Science of Weather
# Case Studies in Functional Genomics
# Ancient Masterpieces of World Literature
# Modern Masterpieces of World Literature
# Humanitarian Response to Conflict and Disaster
# Introduction to Linear Models and Matrix Algebra
# Hinduism Through Its Scriptures.
# Fundamentals of Neuroscience, Part 2: Neurons and Networks
# United States Health Policy
# Introduction to Bioconductor
# The Einstein Revolution
# Principles, Statistical and Computational Tools for Reproducible Data…
# Deploying TinyML
# U.S. Political Institutions: Congress, Presidency, Courts, and Bureaucracy
# Global Health Case Studies from a Biosocial Perspective
# Applications of TinyML
# Strengthening Community Health Worker Programs
# Digital Humanities in Practice: From Research Questions to Results
# Women Making History: Ten Objects, Many Stories
# Practical Improvement Science in Health Care: A Roadmap for Getting…
# Causal Diagrams: Draw Your Assumptions Before Your Conclusions
# MalariaX: Defeating Malaria from the Genes to the Globe
# Religious Literacy: Traditions and Scriptures.
# First Nights - Beethoven's 9th Symphony and the…
# Judaism Through Its Scriptures.
# China Humanities: The Individual in Chinese Culture
# Citizen Politics in America: Public Opinion, Elections, Interest Gro…
# MLOps for Scaling TinyML
# Lessons from Ebola: Preventing the Next Pandemic
# China’s Political and Intellectual Foundations: From Sage Kings to Co…
# Shakespeare's Hamlet: The Ghost
# We the People: Civic Engagement in a Constitutional Democr…
# Sikhism Through Its Scriptures.
# Shakespeare’s Othello: The Moor
# Advanced Bioconductor
# China and Communism
# Contemporary China: The People's Republic, Taiwan, and Hong Kong
# First Nights - Monteverdi’s L’Orfeo and the Birth of Opera
# ChinaX Book Club: Five Authors, Five Books, Five Views of China
# First Nights - Stravinsky’s Rite of Spring: Modernism, Ba…
# 18th-Century Opera: Handel & Mozart
# Shakespeare's The Merchant of Venice: Shylock
# First Nights - Handel's Messiah and Baroque Oratorio
# China’s First Empires and the Rise of Buddhism
# PredictionX: John Snow and the Cholera Epidemic of 1854
# First Nights - Berlioz’s Symphonie Fantastique and Program Music in t…
# Global China: From the Mongols to the Ming
# 19th-Century Opera: Meyerbeer, Wagner, & Verdi
# Cosmopolitan Tang: Aristocratic Culture in China
# Modern China’s Foundations: The Manchus and the Qing
# Invasions, Rebellions, and the Fall of Imperial China
# Creating Modern China: The Republican Period to the Present
# Literati China: Examinations, Neo-Confucianism, an…
# Fundamentals of Neuroscience Final Exam
# The Jewish Bible: Its History As A Physical Artifact
# Electrochemistry
# Energy to Electrochemistry Final Exam
# Introduction to Data Science with Python
# Energy and Thermodynamics
# Entropy and Equilibria
# Structure and Function of Argument: Introduction to Critical…
# CS50's Computer Science for Lawyers
# CS50's Understanding Technology
# CS50's Mobile App Development with React Native
# CS50's AP® Computer Science Principles
# The Ancient Greek Hero
# Ventilación mecánica para pacientes con COVID-19
# Mechanical Ventilation for COVID-19
# Poetry in America: Modernism
# Introduction to American Civics: Presented by Zero-L
# Poetry in America: Whitman
# Saving Schools: Reforming the U.S. Education System
# Poetry in America: The Civil War and Its Aftermath
# JuryX: Deliberations for Social Change
# Readings in Global Health (2017)
# The Book: Monasteries, Schools, and Notaries, Part 2: Introduction to t…
# The Book: Print and Manuscript in Western Europe, Asia and the M…
# The Book: Books in the Medieval Liturgy
# The Book: Scrolls in the Age of the Book
# The Book: Book Sleuthing: What 19th-Century Books C…
# The Book: Monasteries, Schools, and Notaries, Part 1: Reading the Lat…
# The Book: Making and Meaning in the Medieval Manuscript
# The Book: The Medieval Book of Hours: Art and Devotion in the Later M…
# The Book: The History of the Book in the 17th and 18th Century Europe
# The Climate-Energy Challenge

# %%
DF = pd.DataFrame(DATASET)
DF
# Out:
#                                                   Name  Duration  Rating  \
# 0              CS50's Introduction to Computer Science  12 weeks     NaN
# 1       CS50's Introduction to Programming with Python  10 weeks     NaN
# 2    CS50's Introduction to Artificial Intelligence...   7 weeks     NaN
# 3    CS50's Web Programming with Python and JavaScript  12 weeks     NaN
# 4       Exercising Leadership: Foundational Principles   4 weeks     4.6
# ..                                                 ...       ...     ...
# 151  The Book: Monasteries, Schools, and Notaries, ...   3 weeks     NaN
# 152  The Book: Making and Meaning in the Medieval M...   8 weeks     NaN
# 153  The Book: The Medieval Book of Hours: Art and ...   4 weeks     NaN
# 154  The Book: The History of the Book in the 17th ...   1 weeks     NaN
# 155                       The Climate-Energy Challenge   9 weeks     NaN
#
#      Number of ratings  Total enrolled students                Subject  \
# 0                  NaN                6163497.0       Computer Science
# 1                  NaN                1121446.0       Computer Science
# 2                  NaN                1160141.0       Computer Science
# 3                  NaN                1499184.0       Computer Science
# 4                960.0                 636807.0  Business & Management
# ..                 ...                      ...                    ...
# 151                NaN                      NaN             Humanities
# 152                NaN                      NaN             Humanities
# 153                NaN                      NaN             Literature
# 154                NaN                      NaN             Humanities
# 155                NaN                      NaN  Environmental Studies
#
#             Level                                      Prerequisites Language  \
# 0    Introductory                                               None  English
# 1    Introductory                                               None  English
# 2    Introductory    CS50 or prior programming experience in Python.  English
# 3    Intermediate  CS50 or prior programming experience in any la...  English
# 4    Introductory                                               None  English
# ..            ...                                                ...      ...
# 151  Introductory                                               None  English
# 152  Introductory                                               None  English
# 153  Introductory                                               None  English
# 154  Introductory                                               None  English
# 155  Introductory  Learners should be familiar with basic algebra...  English
#
#                                      Associated skills
# 0    Data Structures, C (Programming Language), Sec...
# 1    Data Science, C (Programming Language), Web Br...
# 2    Handwriting Recognition, Mathematical Optimiza...
# 3    Scalability, Cloud Services, React.js, Github,...
# 4                                           Leadership
# ..                                                 ...
# 151                                    Notary Services
# 152                    Collections, Production Process
# 153                                 Literacy, Painting
# 154
# 155                        Forecasting, Greenhouse Gas
#
# [156 rows x 10 columns]

# %%
DF.to_csv("harvardx.csv")

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Name                     156 non-null    object
#  1   Duration                 156 non-null    object
#  2   Rating                   113 non-null    float64
#  3   Number of ratings        113 non-null    float64
#  4   Total enrolled students  125 non-null    float64
#  5   Subject                  156 non-null    object
#  6   Level                    156 non-null    object
#  7   Prerequisites            34 non-null     object
#  8   Language                 156 non-null    object
#  9   Associated skills        156 non-null    object
# dtypes: float64(3), object(7)
# memory usage: 12.3+ KB
